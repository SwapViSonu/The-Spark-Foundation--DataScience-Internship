# %% [markdown]
# # Task4---- Exploratory data Analysis----Terrorism

# %% [markdown]
# ![620bf6454d2ebb00217e6243.jpg](attachment:620bf6454d2ebb00217e6243.jpg)

# %% [markdown]
# **Terrorism, in its broadest sense, is the use of intentional violence and fear to achieve political or ideological aims. The term is used in this regard primarily to refer to intentional violence during peacetime or in the context of war against non-combatants (mostly civilians and neutral military personnel).**

# %% [markdown]
# #### Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# #### Reading DataFrame

# %%
df=pd.read_csv("globalterrorismdb_0718dist.csv",encoding='ISO-8859-1')
df.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(55), int64(22), object(58)
# memory usage: 187.1+ MB

# %% [markdown]
# #### Descriptive Statistics

# %%
df.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997       6.467277      15.505644
# std    1.325957e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991021e+11    1991.000000       4.000000       8.000000
# 50%    2.009022e+11    2009.000000       6.000000      15.000000
# 75%    2.014081e+11    2014.000000       9.000000      23.000000
# max    2.017123e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# ...

# %%
df.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %% [markdown]
# ### Renaming some Important Column

# %%
df=df.rename(columns={'iyear':'Year','imonth':'Month','iday':'Day','country_txt':'Country','region_txt':'Region',
                             'provstate':'State','city':'City','attacktype1_txt':'Attack_type','targtype1_txt':'Target_type',
                             'targsubtype1_txt':'Target_subtype','gname':'Gang_name','weaptype1_txt':'Weapon_type'})

# %%
df.columns
# Out:
# Index(['eventid', 'Year', 'Month', 'Day', 'approxdate', 'extended',
#        'resolution', 'country', 'Country', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %% [markdown]
# ### Important Feature Selection

# %%
df = df[['Year','Month','Day','Country','Region','State','City','Attack_type','Target_type','Target_subtype','Gang_name','Weapon_type']]

# %%
df.head()
# Out:
#    Year  Month  Day             Country                       Region    State  \
# 0  1970      7    2  Dominican Republic  Central America & Caribbean      NaN
# 1  1970      0    0              Mexico                North America  Federal
# 2  1970      1    0         Philippines               Southeast Asia   Tarlac
# 3  1970      1    0              Greece               Western Europe   Attica
# 4  1970      1    0               Japan                    East Asia  Fukouka
#
#             City                     Attack_type                  Target_type  \
# 0  Santo Domingo                   Assassination  Private Citizens & Property
# 1    Mexico city     Hostage Taking (Kidnapping)      Government (Diplomatic)
# 2        Unknown                   Assassination          Journalists & Media
# 3         Athens               Bombing/Explosion      Government (Diplomatic)
# 4        Fukouka  Facility/Infrastructure Attack      Government (Diplomatic)
#
# ...

# %% [markdown]
# ### Checking Nan values

# %%
df.isnull().sum()
# Out:
# Year                  0
# Month                 0
# Day                   0
# Country               0
# Region                0
# State               421
# City                434
# Attack_type           0
# Target_type           0
# Target_subtype    10373
# Gang_name             0
# Weapon_type           0
# dtype: int64

# %%
plt.title('Representing Missing or Nan Value using heatmap')
sns.heatmap(df.isnull())
# Out:
# <Axes: title={'center': 'Representing Missing or Nan Value using heatmap'}>

# %% [markdown]
# ## Filling NaN values

# %%
#Fill NaN values in Target_subtype column as Others`

df['Target_subtype'] = df['Target_subtype'].fillna('others')

# %%
#Fill NaN values in the State column as Unknown
df['State']=df['State'].fillna('Unknown')

# %%
#Fill NaN values in the city column as Unknown

df['City']=df['City'].fillna('Unknown')

# %%
#To make it simpler replace it with Vehicle in Weapon_type Column

df.replace( {"Vehicle (not to include vehicle-borne explosives, i.e., car or truck bombs)": "Vehicle"},inplace = True)

# %%
df.head()
# Out:
#    Year  Month  Day             Country                       Region    State  \
# 0  1970      7    2  Dominican Republic  Central America & Caribbean  Unknown
# 1  1970      0    0              Mexico                North America  Federal
# 2  1970      1    0         Philippines               Southeast Asia   Tarlac
# 3  1970      1    0              Greece               Western Europe   Attica
# 4  1970      1    0               Japan                    East Asia  Fukouka
#
#             City                     Attack_type                  Target_type  \
# 0  Santo Domingo                   Assassination  Private Citizens & Property
# 1    Mexico city     Hostage Taking (Kidnapping)      Government (Diplomatic)
# 2        Unknown                   Assassination          Journalists & Media
# 3         Athens               Bombing/Explosion      Government (Diplomatic)
# 4        Fukouka  Facility/Infrastructure Attack      Government (Diplomatic)
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 12 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Year            181691 non-null  int64
#  1   Month           181691 non-null  int64
#  2   Day             181691 non-null  int64
#  3   Country         181691 non-null  object
#  4   Region          181691 non-null  object
#  5   State           181691 non-null  object
#  6   City            181691 non-null  object
#  7   Attack_type     181691 non-null  object
#  8   Target_type     181691 non-null  object
#  9   Target_subtype  181691 non-null  object
#  10  Gang_name       181691 non-null  object
#  11  Weapon_type     181691 non-null  object
# dtypes: int64(3), object(9)
# memory usage: 16.6+ MB

# %%
df.shape
# Out:
# (181691, 12)

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
Total_countries=df['Country'].nunique()
print("Total %d countries were noted in the data"%Total_countries)
# Out:
# Total 205 countries were noted in the data

# %% [markdown]
# ### Terror Attack region

# %%
print(df['Region'].unique())
# Out:
# ['Central America & Caribbean' 'North America' 'Southeast Asia'
#  'Western Europe' 'East Asia' 'South America' 'Eastern Europe'
#  'Sub-Saharan Africa' 'Middle East & North Africa' 'Australasia & Oceania'
#  'South Asia' 'Central Asia']

# %% [markdown]
# ### Terror Attack Type

# %%
print(df['Attack_type'].unique())
# Out:
# ['Assassination' 'Hostage Taking (Kidnapping)' 'Bombing/Explosion'
#  'Facility/Infrastructure Attack' 'Armed Assault' 'Hijacking' 'Unknown'
#  'Unarmed Assault' 'Hostage Taking (Barricade Incident)']

# %% [markdown]
# ### Terror attack Target Type

# %%
print(df['Target_type'].unique())
# Out:
# ['Private Citizens & Property' 'Government (Diplomatic)'
#  'Journalists & Media' 'Police' 'Utilities' 'Military'
#  'Government (General)' 'Airports & Aircraft' 'Business'
#  'Educational Institution' 'Violent Political Party'
#  'Religious Figures/Institutions' 'Unknown' 'Transportation' 'Tourists'
#  'NGO' 'Telecommunication' 'Food or Water Supply'
#  'Terrorists/Non-State Militia' 'Other' 'Maritime' 'Abortion Related']

# %% [markdown]
# ### Terror Gang name

# %%
print(df['Gang_name'].unique())
# Out:
# ['MANO-D' '23rd of September Communist League' 'Unknown' ...
#  'Fatoni Warriors' 'Minorities of Metropolitan Attacks'
#  'Baloch Republican Party']

# %%
print(df['Gang_name'].nunique())
# Out:
# 3537

# %% [markdown]
# There was a total of 3537 gangs in this dataset.

# %% [markdown]
# ### Top 5 years where most terror attacks occur

# %%
df['Year'].value_counts()[:5]
# Out:
# 2014    16903
# 2015    14965
# 2016    13587
# 2013    12036
# 2017    10900
# Name: Year, dtype: int64

# %% [markdown]
# ### Year-wise terror Attack

# %%
plt.figure(figsize=(20,5));
plt.xticks(rotation = 90)
plt.title('Attacks by Year')
sns.countplot(data=df,x='Year')
# Out:
# <Axes: title={'center': 'Attacks by Year'}, xlabel='Year', ylabel='count'>

# %% [markdown]
# In the most recent year, most terror attacks occurred

# %%
plt.figure(figsize=(20,5));
plt.title('Attacks by Month')
sns.countplot(x=df.Month);

# %% [markdown]
# - Every month has an almost equal number of terror attacks.

# %%
plt.figure(figsize=(20,5));
plt.title('Attacks by Day')
sns.countplot(x=df.Day);

# %% [markdown]
# ### Top 5 Conutry where most terror attacks occur

# %%
df['Country'].value_counts()[:10].plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# - In Iran, more terror attacks occurred,  followed by Pakistan, Afghanistan, India, Colombia, etc.

# %%
plt.figure(figsize=(30,5));
plt.rcParams.update({'font.size':8});
plt.xticks(rotation = 90)
plt.title('Attacks by Country',size=30)
sns.countplot(x=df.Country);

# %%
df.groupby(['Year','Country'])['Attack_type'].count().sort_values(ascending=False)[:10].plot(kind='bar')
# Out:
# <Axes: xlabel='Year,Country'>

# %%
#df['Country'].unique()

# %% [markdown]
# ### Terror Attacks in India

# %%
df_india=df[df['Country']=='India']
df_india.head()
# Out:
#       Year  Month  Day Country      Region        State        City  \
# 1186  1972      2   22   India  South Asia        Delhi   New Delhi
# 2764  1975      1    2   India  South Asia        Bihar  Samastipur
# 3857  1976      5   26   India  South Asia        Delhi   New Delhi
# 5327  1977      9   28   India  South Asia  Maharashtra      Bombay
# 7337  1979      1   13   India  South Asia        Assam     Unknown
#
#             Attack_type           Target_type  \
# 1186          Hijacking   Airports & Aircraft
# 2764  Bombing/Explosion  Government (General)
# 3857  Bombing/Explosion   Airports & Aircraft
# 5327          Hijacking   Airports & Aircraft
# 7337      Armed Assault                Police
#
#                                          Target_subtype  \
# 1186                       Aircraft (not at an airport)
# 2764  Government Personnel (excluding police, military)
# 3857                                            Airport
# ...

# %%
plt.figure(figsize=(20,5));
plt.xticks(rotation = 90)
plt.title('Attack by Year in India',size=30)
ax=sns.countplot(data=df_india,x='Year')
for container in ax.containers:
    ax.bar_label(container)

# %% [markdown]
# - After 2007 terror attack in Indias Drastically increased
# - In year 2017 more terror attack occured as compared to other,

# %% [markdown]
# ### State wise terror Attack count in india

# %%
df_india['State'].value_counts()
# Out:
# Jammu and Kashmir    2454
# Assam                1151
# Manipur              1100
# Chhattisgarh          979
# Punjab                949
# Jharkhand             887
# Bihar                 688
# West Bengal           650
# Odisha                428
# Maharashtra           302
# Meghalaya             294
# Andhra Pradesh        251
# Orissa                221
# Delhi                 208
# Uttar Pradesh         201
# Tamil Nadu            164
# Unknown               157
# Tripura               117
# Nagaland              115
# Kerala                 98
# Gujarat                85
# Madhya Pradesh         75
# Karnataka              71
# Haryana                50
# Chandigarh             47
# Rajasthan              43
# Andhra pradesh         41
# Mizoram                27
# Uttaranchal            24
# Himachal Pradesh       24
# Arunachal Pradesh      24
# Telangana              24
# Goa                     5
# Sikkim                  4
# Puducherry              2
# ...

# %% [markdown]
# ### State wise top most terror  attack  count with their respective year

# %%
df_india.groupby(['Year','State'])['Attack_type'].count().sort_values(ascending=False)[:10].plot(kind='bar')
# Out:
# <Axes: xlabel='Year,State'>

# %%
plt.figure(figsize=(20,5))
plt.title('Most Terror Attack type in India',size=30)
ax=sns.countplot(data=df_india,x='Attack_type',order=df_india['Attack_type'].value_counts().index)
for container in ax.containers:
    ax.bar_label(container)

# %% [markdown]
# ### Top 10 terror gang name in India

# %%
plt.figure(figsize=(20,5))
plt.title('Top 10 terror gang name in India',size=30)
df_india['Gang_name'].value_counts().head(10).plot(kind="bar")
# Out:
# <Axes: title={'center': 'Top 10 terror gang name in India'}>

# %%
plt.figure(figsize=(20,5))
plt.title('Weapon used in India terror attack',size=30)
ax=sns.countplot(df_india['Weapon_type'])
for container in ax.containers:
    ax.bar_label(container)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:2263, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:2273, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %% [markdown]
# ### Top 10 Region where terror attack happened

# %%
df['Region'].value_counts()[:10].plot(kind='bar')

# %% [markdown]
# ### Top 10 Region where Most Terror Attack Occured

# %%
df['Region'].value_counts().head(10)

# %%
plt.figure(figsize=(28,10));
plt.rcParams.update({'font.size':10});
plt.xticks(rotation = 0)
plt.title('Attacks by Region',size=30)
sns.countplot(x=df.Region,order=df.Region.value_counts().index);

# %% [markdown]
# ### Top 10 State where Most Terror Attack Occured

# %%
df['State'].value_counts().head(10)

# %%
df['Target_subtype'].value_counts().head(10)

# %% [markdown]
# ### Top 10 City mostly affected by terror

# %%
df['City'].value_counts().head(10)

# %% [markdown]
# ### Most Terror Attack Type

# %%
df['Attack_type'].value_counts().head(10)

# %% [markdown]
# ### Main Target type of Terror

# %%
df['Target_type'].value_counts().head(10)

# %% [markdown]
# ### Top 10 Ganng Name with their Terror Count

# %%
df['Gang_name'].value_counts().head(10)

# %% [markdown]
# ### Main weapon type for terror

# %%
df['Weapon_type'].value_counts().head(5)

# %%
plt.figure(figsize=(20,5));
plt.title('Terror Attack Weapon Type',size=30)
sns.countplot(x=df.Weapon_type,palette='Set1',order=df.Weapon_type.value_counts().index);

# %% [markdown]
# ## Results of Analysis

# %% [markdown]
# - Most of the attacks were attacked through explosives and then through firearms.
# - Attacks were more during 2014 and then in 2015. When compared to attacks from 1970 onwards, the last 6 years scored a maximum. - But from 2014 onwards count started decreasing.
# - Almost Every day has the same contribution but attacks were low during 31st and high during 15th and 1st.
# - Iraq dominates all the countries and it has the highest number of attacks and then Pakistan, Afghanistan, and India follow it.
# - The Middle East& North Africa leads 1st among all the regions and then South Asia takes 2nd place.
# - For most of the attacks, the target is Private Citizens& property and the next Military leads.
# - Most of the attacks were through either Bombing or Explosion.
